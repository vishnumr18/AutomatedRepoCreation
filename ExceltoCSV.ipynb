# %%
import pandas as pd

# %%
df = pd.read_csv("GitHub UserID.csv")
df
# Out:
#            Team ID           Team Name             GitHub ID
# 0    HZ25AMC-IOT01             Craft.Co      Yashwanthgethub
# 1    HZ25AMC-IOT02  404 Brain not found              radz_15
# 2    HZ25AMC-IOT03        The Mavericks          KAUSHALK123
# 3    HZ25AMC-IOT04          Console.log          Premraviraj
# 4    HZ25AMC-IOT05         ElectroStorm     Amitkumarsingh01
# 5    HZ25AMC-IOT06        Farmion Force               heatly
# 6    HZ25AMC-IOT07             Heralds         altafansari22
# 7    HZ25AMC-IOT08            SuperNova  santhoshkumar150822
# 8    HZ25AMC-IOT09           Hacktastic           AryanR1721
# 9    HZ25AMC-IOT10              Swastik         Sharath-mani
# 10  HZ25AMC-AIML01               Vortex              Elson18
# 11  HZ25AMC-AIML04               Matrix          Pavan-RESTs
# 12  HZ25AMC-AIML06         Tech Titans              Amutha30
# 13  HZ25AMC-AIML07            Holobites           pranava-mk
# ...

# %%
df["TeamInfo"] = df['Team Name '] + ' (' + df['Team ID'] + ')'

# %%
df
# Out:
#            Team ID           Team Name             GitHub ID  \
# 0    HZ25AMC-IOT01             Craft.Co      Yashwanthgethub
# 1    HZ25AMC-IOT02  404 Brain not found              radz_15
# 2    HZ25AMC-IOT03        The Mavericks          KAUSHALK123
# 3    HZ25AMC-IOT04          Console.log          Premraviraj
# 4    HZ25AMC-IOT05         ElectroStorm     Amitkumarsingh01
# 5    HZ25AMC-IOT06        Farmion Force               heatly
# 6    HZ25AMC-IOT07             Heralds         altafansari22
# 7    HZ25AMC-IOT08            SuperNova  santhoshkumar150822
# 8    HZ25AMC-IOT09           Hacktastic           AryanR1721
# 9    HZ25AMC-IOT10              Swastik         Sharath-mani
# 10  HZ25AMC-AIML01               Vortex              Elson18
# 11  HZ25AMC-AIML04               Matrix          Pavan-RESTs
# 12  HZ25AMC-AIML06         Tech Titans              Amutha30
# 13  HZ25AMC-AIML07            Holobites           pranava-mk
# ...

# %%
result = df[['TeamInfo', 'GitHub ID']]
result
# Out:
#                                TeamInfo            GitHub ID
# 0              Craft.Co (HZ25AMC-IOT01)      Yashwanthgethub
# 1   404 Brain not found (HZ25AMC-IOT02)              radz_15
# 2         The Mavericks (HZ25AMC-IOT03)          KAUSHALK123
# 3           Console.log (HZ25AMC-IOT04)          Premraviraj
# 4          ElectroStorm (HZ25AMC-IOT05)     Amitkumarsingh01
# 5         Farmion Force (HZ25AMC-IOT06)               heatly
# 6              Heralds  (HZ25AMC-IOT07)        altafansari22
# 7             SuperNova (HZ25AMC-IOT08)  santhoshkumar150822
# 8            Hacktastic (HZ25AMC-IOT09)           AryanR1721
# 9               Swastik (HZ25AMC-IOT10)         Sharath-mani
# 10              Vortex (HZ25AMC-AIML01)              Elson18
# 11              Matrix (HZ25AMC-AIML04)          Pavan-RESTs
# 12        Tech Titans  (HZ25AMC-AIML06)             Amutha30
# 13           Holobites (HZ25AMC-AIML07)           pranava-mk
# ...

# %%
len(result)
# Out:
# 26

# %%
result.to_csv('MergedFile.csv', index=False)
